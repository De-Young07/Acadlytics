# %%
import pandas as pd
import hashlib

df = pd.read_csv("C:/Users/USER/Acadlytics/data/sample/sample_data.csv")

print("="*50)
print("DATA QUALITY REPORT")
print("="*50)
print(f"Shape: {df.shape}")
print(f"Columns: {list(df.columns)}")
print(f"Missing values:\n{df.isnull().sum()}")
print(f"Grade distribution:\n{df['grade'].value_counts()}")
# Out:
# ==================================================
# DATA QUALITY REPORT
# ==================================================
# Shape: (4, 7)
# Columns: ['student_id_hashed', 'course_code', 'semester', 'academic_year', 'grade', 'student_level', 'department']
# Missing values:
# student_id_hashed    0
# course_code          0
# semester             0
# academic_year        0
# grade                0
# student_level        0
# department           0
# dtype: int64
# Grade distribution:
# grade
# B    1
# A    1
# F    1
# C    1
# Name: count, dtype: int64
